# %% [markdown]
# <h1><b>Content Based Filtering : Kampus Merdeka</b></h1>

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
import re
import random

df = pd.read_csv("dataset/kampusmerdeka_dataset.csv")

df
# Out:
#                          partner_name  \
# 0                      Nabil Syahfiar
# 1          PT Orbit Ventura Indonesia
# 2           PT Mitra Semeru Indonesia
# 3        PT Nurul Fikri Cipta Inovasi
# 4             PT Ruang Raya Indonesia
# 5         PT LENTERA BANGSA BENDERANG
# 6                   PT DWI INTI PUTRA
# 7            PT. INDOBIT DIGITAL RAYA
# 8      PT Mitra Integrasi Informatika
# 9         PT LENTERA BANGSA BENDERANG
# 10  PT Hacktivate Teknologi Indonesia
# 11    PT Nodeflux Teknologi Indonesia
# 12               PT Pundi Mas Berjaya
# 13                    PT GIT SOLUTION
# 14  PT Telkom Indonesia (Persero) Tbk
# 15          PT TELEKOMUNIKASI SELULAR
# 16         PT Widya Inovasi Indonesia
# 17   PT Bejana Investidata Globalindo
# 18    PT Investree Radhika Jaya Group
# 19     PT Generasi Anak Muda Berkarya
# 20                UPT Solo Technopark
#
#                                               address  \
# 0               Kaliwungu, Kendal, Jawa Tengah, 51372
# 1   Veteran RI Building 15th Floor Unit Z15-002, P...
# 2   Jl. Mampang Prapatan Raya no 84A, Tegal Parang...
# 3   Jl. Situ Indah No.116 RT. 006 RW. 010 Kel. Tug...
# 4   Jl. Dr. Saharjo No.161, Manggarai Selatan, Teb...
# 5                             (Alamat Tidak Tersedia)
# 6                             (Alamat Tidak Tersedia)
# 7   Educenter building unit 22218 Kav Commercial I...
# 8   APL Tower Lantai 37, Jl. Letjen S. Parman Kav....
# 9                             (Alamat Tidak Tersedia)
# 10  Gedung Aquarius Lt. 1&2, Jl. Sultan Iskandar M...
# 11                                  Jakarta Indonesia
# 12  Jl. Kw. Industri Tunas 2 No.7D, Belian, Kec. B...
# 13                            (Alamat Tidak Tersedia)
# 14                               Jl Japati 1, Bandung
# 15  The Telkom Hub, Jl. Gatot Subroto No.Kav. 52, ...
# 16  Jl. Palagan Tentara Pelajar KM 7.5 No.31A, Mud...
# 17  Jl. Cipaku Indah III No. 14, Bandung, Jawa Bar...
# 18  AIA Central 21st Floor, Jalan Jendral Sudirman...
# 19  Grand Slipi Tower, CHR Offce Unit O Lt 9, Jl. ...
# 20  Jl. Ki Hajar Dewantara No.19, Jebres, Kec. Jeb...
#
#                                           description           program  \
# 0   ai, object oriented programming, oop, web prog...            Kuliah
# 1   3.AI Project Cycle 2.AI Research Methods 4.Pyt...  Studi Independen
# 2   1.AI Technology Logic and Concept 2.AI Project...  Studi Independen
# 3   Desain Web Version Control System (VCS): Git/G...  Studi Independen
# 4   Final Project Software Engineering: Implementi...  Studi Independen
# 5   Know the Introduction to the World of Programm...  Studi Independen
# 6   Capstone Project Support Group Introduction to...  Studi Independen
# 7   Program Onboarding Data Collection Overview of...  Studi Independen
# 8   Introduction to Programming Front-End Programm...  Studi Independen
# 9   Perform unit testing and deployment Master the...  Studi Independen
# 10  Exploration of Various Applications of Functio...  Studi Independen
# 11  MLOps and Continous Improvement on AI Systems ...            Magang
# 12  Analysis of a system Dynamic teamwork Creation...            Magang
# 13  Understanding of application design, use of AP...            Magang
# 14  Software Development Life-Cycle Data Managemen...            Magang
# 15  Data Mining Data and Statistical Analytic Soft...            Magang
# 16  Commit & push code UI implementation Collabora...            Magang
# 17  Implementation of REST API Implementation of c...            Magang
# 18  Vue La Laravel Introduction Final Project & Pr...            Magang
# 19  Applying Design on Android Storing Data into L...            Magang
# 20  Adaptability Creativity Leadership and Teamwor...            Magang
#
#                         course_name
# 0                       Mata Kuliah
# 1                         AI 4 Jobs
# 2                   AI for StartUps
# 3   Akademi Fullstack Web Developer
# 4               Backend Engineering
# 5                Backend Javascript
# 6                      Data Analyst
# 7       Data Analytics for Business
# 8              Full Stack Developer
# 9                     Fullstack Web
# 10   Golang for Back End Programmer
# 11                      AI Engineer
# 12                  Analisis Sistem
# 13                Android Developer
# 14               Back-end Developer
# 15            Data Analytics Intern
# 16              Front-End Developer
# 17             Full-Stack Developer
# 18               Fullstack Engineer
# 19       Mobile Android Development
# 20                    Web Developer

# %% [markdown]
# <br>
# <h2><b>1. Ikhtisar</b></h2>

# %%
df.describe()
# Out:
#                        partner_name                  address  \
# count                            21                       21
# unique                           20                       18
# top     PT LENTERA BANGSA BENDERANG  (Alamat Tidak Tersedia)
# freq                              2                        4
#
#                                               description           program  \
# count                                                  21                21
# unique                                                 21                 3
# top     ai, object oriented programming, oop, web prog...  Studi Independen
# freq                                                    1                10
#
#         course_name
# count            21
# unique           21
# top     Mata Kuliah
# freq              1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   partner_name  21 non-null     object
#  1   address       21 non-null     object
#  2   description   21 non-null     object
#  3   program       21 non-null     object
#  4   course_name   21 non-null     object
# dtypes: object(5)
# memory usage: 968.0+ bytes

# %% [markdown]
# <br>
# <h2><b>2. Deskripsi Modul & Kompetensi</b> (Sebelum Preprocessing)</h2>

# %%
def print_description(index):
    example = df[df.index == index][['description', 'partner_name', 'program', 'course_name']].values[0]
    if len(example) > 0:
        print(example[0], '\n')
        print('Nama Mitra\t:', example[1])
        print('Program\t:', example[2])
        print('Kursus atau Posisi\t:', example[3])
        print()

# %%
print_description(1)
# Out:
# 3.AI Project Cycle 2.AI Research Methods 4.Python 1 programming.AI Technology Logic and Concept 6.Final Project 5.Professional Ethics & Company Skills
#
# Nama Mitra	: PT Orbit Ventura Indonesia
# Program	: Studi Independen
# Kursus atau Posisi	: AI 4 Jobs

# %% [markdown]
# <br>
# <h2><b>3. Text Preprocessing</b></h2>

# %%
clean_spcl = re.compile('[/(){}\[\]\|@,;]')
clean_symbol = re.compile('[^0-9a-z #+_]')
stopworda = set(stopwords.words('english'))

def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = text.lower() # lowercase text
    text = clean_spcl.sub(' ', text)
    text = clean_symbol.sub('', text)
    text = ' '.join(word for word in text.split() if word not in stopworda) # hapus stopword dari kolom deskripsi
    return text
    
df['desc_clean'] = df['description'].apply(clean_text)

# %%
df.head()
# Out:
#                    partner_name  \
# 0                Nabil Syahfiar
# 1    PT Orbit Ventura Indonesia
# 2     PT Mitra Semeru Indonesia
# 3  PT Nurul Fikri Cipta Inovasi
# 4       PT Ruang Raya Indonesia
#
#                                              address  \
# 0              Kaliwungu, Kendal, Jawa Tengah, 51372
# 1  Veteran RI Building 15th Floor Unit Z15-002, P...
# 2  Jl. Mampang Prapatan Raya no 84A, Tegal Parang...
# 3  Jl. Situ Indah No.116 RT. 006 RW. 010 Kel. Tug...
# 4  Jl. Dr. Saharjo No.161, Manggarai Selatan, Teb...
#
#                                          description           program  \
# 0  ai, object oriented programming, oop, web prog...            Kuliah
# 1  3.AI Project Cycle 2.AI Research Methods 4.Pyt...  Studi Independen
# 2  1.AI Technology Logic and Concept 2.AI Project...  Studi Independen
# 3  Desain Web Version Control System (VCS): Git/G...  Studi Independen
# 4  Final Project Software Engineering: Implementi...  Studi Independen
#
#                        course_name  \
# 0                      Mata Kuliah
# 1                        AI 4 Jobs
# 2                  AI for StartUps
# 3  Akademi Fullstack Web Developer
# 4              Backend Engineering
#
#                                           desc_clean
# 0  ai object oriented programming oop web program...
# 1  3ai project cycle 2ai research methods 4python...
# 2  1ai technology logic concept 2ai project cycle...
# 3  desain web version control system vcs git gith...
# 4  final project software engineering implementin...

# %% [markdown]
# <br>
# <h2><b>4. Deskripsi Modul & Kompetensi</b> (Setelah Preprocessing)</h2>

# %%
# Deskripsi kedua (Setelah preprocessing)
def print_description_clean(index):
    example = df[df.index == index][['desc_clean', 'partner_name', 'program', 'course_name']].values[0]
    if len(example) > 0:
        print(example[0], '\n')
        print('Nama Mitra\t:', example[1])
        print('Program\t:', example[2])
        print('Kursus atau Posisi\t:', example[3])
        print()

# %%
print_description_clean(1)
# Out:
# 3ai project cycle 2ai research methods 4python 1 programmingai technology logic concept 6final project 5professional ethics company skills
#
# Nama Mitra	: PT Orbit Ventura Indonesia
# Program	: Studi Independen
# Kursus atau Posisi	: AI 4 Jobs

# %% [markdown]
# <br>
# <h2><b>5. TF-IDF & Cosine Similarity</b></h2>

# %%
df.set_index('partner_name', inplace=True)
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(df['desc_clean'])
cos_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
cos_sim
# Out:
# array([[1.        , 0.        , 0.        , 0.04208615, 0.071635  ,
#         0.0911061 , 0.00604063, 0.03918833, 0.11617208, 0.04431005,
#         0.03439369, 0.06674163, 0.00761257, 0.05747614, 0.02441371,
#         0.02372035, 0.0065789 , 0.03299428, 0.01401157, 0.02690397,
#         0.01122623],
#        [0.        , 1.        , 0.32011442, 0.01223473, 0.019006  ,
#         0.00592109, 0.00863442, 0.01306972, 0.        , 0.0132483 ,
#         0.        , 0.01504565, 0.        , 0.        , 0.        ,
#         0.        , 0.        , 0.        , 0.01321821, 0.        ,
#         0.03193534],
#        [0.        , 0.32011442, 1.        , 0.01363991, 0.0114529 ,
#         0.00660113, 0.0096261 , 0.00791115, 0.        , 0.00738494,
#         0.        , 0.01677366, 0.        , 0.        , 0.        ,
#         0.        , 0.        , 0.        , 0.01473634, 0.        ,
#         0.01583513],
#        [0.04208615, 0.01223473, 0.01363991, 1.        , 0.04605612,
#         0.0458314 , 0.00361473, 0.00987036, 0.        , 0.02799068,
#         0.01255183, 0.00311838, 0.00461574, 0.01197225, 0.        ,
#         0.        , 0.01740074, 0.04173924, 0.0464956 , 0.00545675,
#         0.00594631],
#        [0.071635  , 0.019006  , 0.0114529 , 0.04605612, 1.        ,
#         0.14590607, 0.00982198, 0.02952062, 0.05971275, 0.14254264,
#         0.05633024, 0.02146836, 0.00383752, 0.03373358, 0.03649929,
#         0.01104327, 0.02562331, 0.03942403, 0.11070723, 0.03423444,
#         0.02104468],
#        [0.0911061 , 0.00592109, 0.00660113, 0.0458314 , 0.14590607,
#         1.        , 0.01264908, 0.0289355 , 0.08154567, 0.21240539,
#         0.08209398, 0.0233061 , 0.00690238, 0.0764933 , 0.03139597,
#         0.01497499, 0.        , 0.0707086 , 0.03982492, 0.01505816,
#         0.        ],
#        [0.00604063, 0.00863442, 0.0096261 , 0.00361473, 0.00982198,
#         0.01264908, 1.        , 0.07258601, 0.08579723, 0.00257194,
#         0.        , 0.00220073, 0.        , 0.00650355, 0.00341842,
#         0.01874809, 0.        , 0.        , 0.01712381, 0.0043181 ,
#         0.00419649],
#        [0.03918833, 0.01306972, 0.00791115, 0.00987036, 0.02952062,
#         0.0289355 , 0.07258601, 1.        , 0.02685276, 0.01618985,
#         0.01002459, 0.01775254, 0.05334471, 0.01719775, 0.02479193,
#         0.16425959, 0.        , 0.        , 0.0213037 , 0.04310775,
#         0.0253292 ],
#        [0.11617208, 0.        , 0.        , 0.        , 0.05971275,
#         0.08154567, 0.08579723, 0.02685276, 1.        , 0.02440744,
#         0.02090069, 0.        , 0.        , 0.0617181 , 0.01781956,
#         0.        , 0.        , 0.        , 0.02759831, 0.        ,
#         0.        ],
#        [0.04431005, 0.0132483 , 0.00738494, 0.02799068, 0.14254264,
#         0.21240539, 0.00257194, 0.01618985, 0.02440744, 1.        ,
#         0.0726429 , 0.02692748, 0.00772197, 0.04048951, 0.04209774,
#         0.        , 0.03040932, 0.06489864, 0.05738608, 0.03711843,
#         0.        ],
#        [0.03439369, 0.        , 0.        , 0.01255183, 0.05633024,
#         0.08209398, 0.        , 0.01002459, 0.02090069, 0.0726429 ,
#         1.        , 0.        , 0.00528195, 0.02264957, 0.00494334,
#         0.        , 0.        , 0.05601685, 0.        , 0.        ,
#         0.        ],
#        [0.06674163, 0.01504565, 0.01677366, 0.00311838, 0.02146836,
#         0.0233061 , 0.00220073, 0.01775254, 0.        , 0.02692748,
#         0.        , 1.        , 0.01928197, 0.00497274, 0.02497087,
#         0.        , 0.02935766, 0.        , 0.03701546, 0.00921619,
#         0.01100468],
#        [0.00761257, 0.        , 0.        , 0.00461574, 0.00383752,
#         0.00690238, 0.        , 0.05334471, 0.        , 0.00772197,
#         0.00528195, 0.01928197, 1.        , 0.00368026, 0.        ,
#         0.        , 0.        , 0.04153526, 0.        , 0.00551389,
#         0.01225599],
#        [0.05747614, 0.        , 0.        , 0.01197225, 0.03373358,
#         0.0764933 , 0.00650355, 0.01719775, 0.0617181 , 0.04048951,
#         0.02264957, 0.00497274, 0.00368026, 1.        , 0.02944848,
#         0.        , 0.00954162, 0.03772841, 0.02986834, 0.0777424 ,
#         0.0118374 ],
#        [0.02441371, 0.        , 0.        , 0.        , 0.03649929,
#         0.03139597, 0.00341842, 0.02479193, 0.01781956, 0.04209774,
#         0.00494334, 0.02497087, 0.        , 0.02944848, 1.        ,
#         0.02512279, 0.        , 0.01862614, 0.00671424, 0.02478293,
#         0.01931149],
#        [0.02372035, 0.        , 0.        , 0.        , 0.01104327,
#         0.01497499, 0.01874809, 0.16425959, 0.        , 0.        ,
#         0.        , 0.        , 0.        , 0.        , 0.02512279,
#         1.        , 0.        , 0.        , 0.        , 0.03173472,
#         0.        ],
#        [0.0065789 , 0.        , 0.        , 0.01740074, 0.02562331,
#         0.        , 0.        , 0.        , 0.        , 0.03040932,
#         0.        , 0.02935766, 0.        , 0.00954162, 0.        ,
#         0.        , 1.        , 0.03386671, 0.        , 0.03681648,
#         0.02020125],
#        [0.03299428, 0.        , 0.        , 0.04173924, 0.03942403,
#         0.0707086 , 0.        , 0.        , 0.        , 0.06489864,
#         0.05601685, 0.        , 0.04153526, 0.03772841, 0.01862614,
#         0.        , 0.03386671, 1.        , 0.02208688, 0.        ,
#         0.02288344],
#        [0.01401157, 0.01321821, 0.01473634, 0.0464956 , 0.11070723,
#         0.03982492, 0.01712381, 0.0213037 , 0.02759831, 0.05738608,
#         0.        , 0.03701546, 0.        , 0.02986834, 0.00671424,
#         0.        , 0.        , 0.02208688, 1.        , 0.00848132,
#         0.0064243 ],
#        [0.02690397, 0.        , 0.        , 0.00545675, 0.03423444,
#         0.01505816, 0.0043181 , 0.04310775, 0.        , 0.03711843,
#         0.        , 0.00921619, 0.00551389, 0.0777424 , 0.02478293,
#         0.03173472, 0.03681648, 0.        , 0.00848132, 1.        ,
#         0.        ],
#        [0.01122623, 0.03193534, 0.01583513, 0.00594631, 0.02104468,
#         0.        , 0.00419649, 0.0253292 , 0.        , 0.        ,
#         0.        , 0.01100468, 0.01225599, 0.0118374 , 0.01931149,
#         0.        , 0.02020125, 0.02288344, 0.0064243 , 0.        ,
#         1.        ]])

# %%
# Set index utama di kolom 'name'
indices = pd.Series(df.index)
indices[:21]
# Out:
# 0                        Nabil Syahfiar
# 1            PT Orbit Ventura Indonesia
# 2             PT Mitra Semeru Indonesia
# 3          PT Nurul Fikri Cipta Inovasi
# 4               PT Ruang Raya Indonesia
# 5           PT LENTERA BANGSA BENDERANG
# 6                     PT DWI INTI PUTRA
# 7              PT. INDOBIT DIGITAL RAYA
# 8        PT Mitra Integrasi Informatika
# 9           PT LENTERA BANGSA BENDERANG
# 10    PT Hacktivate Teknologi Indonesia
# 11      PT Nodeflux Teknologi Indonesia
# 12                 PT Pundi Mas Berjaya
# 13                      PT GIT SOLUTION
# 14    PT Telkom Indonesia (Persero) Tbk
# 15            PT TELEKOMUNIKASI SELULAR
# 16           PT Widya Inovasi Indonesia
# 17     PT Bejana Investidata Globalindo
# 18      PT Investree Radhika Jaya Group
# 19       PT Generasi Anak Muda Berkarya
# 20                  UPT Solo Technopark
# Name: partner_name, dtype: object

# %% [markdown]
# <br>
# <h2><b>6. Modelling</b></h2>

# %%
def recommendations(name, cos_sim = cos_sim):
    
    recommended_mbkm = {'partner_name': [],
                       'address': [],
                       'program': [],
                       'course_name': []}
    
    # Mengambil nama hotel berdasarkan variabel indicies
    idx = indices[indices == name].index[0]

    # Membuat series berdasarkan skor kesamaan
    score_series = pd.Series(cos_sim[idx]).sort_values(ascending = False)

    # mengambil index dan dibuat 10 baris rekomendasi terbaik
    top_10_indexes = list(score_series.iloc[1:11].index)

    print('Daftar Rekomendasi')
    print("="*50)
    
    for i in top_10_indexes:
      
      if list(df['program'])[i] == "Magang":
        kursus_or_posisi = "Posisi"
      else:
        kursus_or_posisi = "Kursus"
      
      print()
      print('Mitra\t:', list(df.index)[i])
      print('Program\t:', list(df['program'])[i])
      print(f'{kursus_or_posisi}\t:', list(df['course_name'])[i])
      print()
      print("="*50)

# %% [markdown]
# <br>
# <h2><b>7. Prediksi</b></h2>

# %%
recommendations('Nabil Syahfiar')
# Out:
# Daftar Rekomendasi
# ==================================================
#
# Mitra	: PT Mitra Integrasi Informatika
# Program	: Studi Independen
# Kursus	: Full Stack Developer
#
# ==================================================
#
# Mitra	: PT LENTERA BANGSA BENDERANG
# Program	: Studi Independen
# Kursus	: Backend Javascript
#
# ==================================================
#
# Mitra	: PT Ruang Raya Indonesia
# Program	: Studi Independen
# Kursus	: Backend Engineering
#
# ==================================================
#
# Mitra	: PT Nodeflux Teknologi Indonesia
# Program	: Magang
# Posisi	: AI Engineer
#
# ==================================================
#
# Mitra	: PT GIT SOLUTION
# Program	: Magang
# Posisi	: Android Developer
#
# ==================================================
#
# Mitra	: PT LENTERA BANGSA BENDERANG
# Program	: Studi Independen
# Kursus	: Fullstack Web
#
# ==================================================
#
# Mitra	: PT Nurul Fikri Cipta Inovasi
# Program	: Studi Independen
# Kursus	: Akademi Fullstack Web Developer
#
# ==================================================
#
# Mitra	: PT. INDOBIT DIGITAL RAYA
# Program	: Studi Independen
# Kursus	: Data Analytics for Business
#
# ==================================================
#
# Mitra	: PT Hacktivate Teknologi Indonesia
# Program	: Studi Independen
# Kursus	: Golang for Back End Programmer
#
# ==================================================
#
# Mitra	: PT Bejana Investidata Globalindo
# Program	: Magang
# Posisi	: Full-Stack Developer
#
# ==================================================
